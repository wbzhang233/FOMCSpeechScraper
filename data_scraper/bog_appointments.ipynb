# %% [markdown]
# # 美联储理事会BOG 理事任期数据爬取
#
# @author: WUBIN ZHANG / 01208663
#
# @date: Oct 16, 2024

# %%
import os
import pickle
import sys
sys.path.append('../')
import time
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from utils.file_saver import json_dump
from utils.common import parse_datestring
from datetime import datetime

today = datetime.now().strftime("%b. %d, %Y")

# %% [markdown]
# ## 任期表数据爬取

# %%
def extract_table_data(table_element):
    rows = table_element.find_all('tr')
    data = []
    for row in rows:
        cols = row.find_all(["th", "td"])
        cols = [col.text.strip() for col in cols]
        data.append(cols)
    return data

def extract_tables():
    # 替换为你的ChromeDriver路径
    driver = webdriver.Chrome()

    # 访问目标网址
    url = "https://www.federalreserve.gov/aboutthefed/bios/board/boardmembership.htm"
    driver.get(url)
    time.sleep(3)  # 等待页面加载完成
    
    # 获取所有表格元素
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    tables = soup.find_all('table')

    needed_tables = {}
    for table in tables:
        previous_h4 = table.find_previous("h4")
        if previous_h4 and previous_h4.text.startswith('Chairs and Active Executive Officers of the Board of Governors of the Federal Reserve'):
            needed_tables['ChairTable'] = table
        elif previous_h4 and previous_h4.text.startswith('Vice Chair of the Board of Governors of the Federal Reserve System'):
            needed_tables['ViceChairTable'] = table
        elif previous_h4 and previous_h4.text.startswith('Vice Chair for Supervision of the Board of Governors of the Federal Reserve System'):
            needed_tables['SupervisionViceChairTable'] = table
        elif previous_h4 and previous_h4.text.startswith(
            "Members of the Federal Reserve Board"
        ):
            needed_tables['GovernorsTable'] = table
        else:
            continue

    # 提取每个表格的数据
    chair_table = extract_table_data(needed_tables['ChairTable']) # tables[3]
    vice_chair_table = extract_table_data(needed_tables["ViceChairTable"])  # tables[5]
    supervision_vice_chair_table = extract_table_data(tables[7])  # tables[7]
    governors_table = extract_table_data(tables[8])  # tables[8]

    # 打印结果检查
    print("Chair Table:", chair_table)
    print("Vice Chair Table:", vice_chair_table)
    print("Supervision Vice Chair Table:", supervision_vice_chair_table)
    print("Governors Table:", governors_table)
    return chair_table, vice_chair_table, supervision_vice_chair_table, governors_table


FILENAME = "../data/bog/board_of_governors_terms.pkl"
if os.path.exists(FILENAME):
    print(f"{FILENAME} exists, skipping extraction. Loading...")
    with open(FILENAME, "rb") as f:
        chair_table, vice_chair_table, supervision_vice_chair_table, governors_table = pickle.load(f)
else:
    chair_table, vice_chair_table, supervision_vice_chair_table, governors_table = extract_tables()
    with open(FILENAME, "wb") as f:
        pickle.dump([chair_table, vice_chair_table, supervision_vice_chair_table, governors_table], f)
# Out:
# ../data/bog/board_of_governors_terms.pkl exists, skipping extraction. Loading...

# %%
json_dump(chair_table, "../data/bog/chair_table.json")
json_dump(vice_chair_table, "../data/bog/vice_chair_table.json")
json_dump(supervision_vice_chair_table, "../data/bog/supervision_vice_chair_table.json")
json_dump(governors_table, "../data/bog/governors_table.json")

# %% [markdown]
# ### 主席任期表

# %%
def amend_date(date: str):
    try:
        dt, year = date.split(",")
        if len(year.strip())>=4:
            year = year.strip()[:4]
        return dt + ', ' + year
    except ValueError:
        return None

def split_term(term_str: str):
    try:
        start_date, end_date = term_str.split("-", maxsplit=2)
        start_date = amend_date(start_date.strip())
        end_date = amend_date(end_date.strip())
        return pd.Series([start_date, end_date])
    except ValueError:
        return pd.Series([None, None])

split_term("Feb. 1, 19362 - Jan. 31, 1948")
# Out:
# 0     Feb. 1, 1936
# 1    Jan. 31, 1948
# dtype: object

# %%
chairs = pd.DataFrame(chair_table[1:], columns=chair_table[0])
# chairs[["begin_date", "end_date"]] = chairs["Date of term"].str.split(" - ", expand=True)
chairs[["TermBeginDate", "TermEndDate"]] = chairs["Date of term"].apply(split_term)
# 保存到本地
chairs.to_csv("../data/bog/chairs.csv", index=False)
chairs
# Out:
#                     Date of term            Appointee  TermBeginDate  \
# 0  Feb. 1, 19362 - Jan. 31, 1948   Marriner S. Eccles   Feb. 1, 1936
# 1  Apr. 15, 1948 - Mar. 31, 1951     Thomas B. McCabe  Apr. 15, 1948
# 2   Apr. 2, 1951 - Jan. 31, 1970  Wm. McC. Martin, Jr   Apr. 2, 1951
# 3   Feb. 1, 1970 - Jan. 31, 1978      Arthur F. Burns   Feb. 1, 1970
# 4    Mar. 8, 1978 - Aug. 6, 1979    G. William Miller   Mar. 8, 1978
# 5   Aug. 6, 1979 - Aug. 11, 1987      Paul A. Volcker   Aug. 6, 1979
# 6  Aug. 11, 1987 - Jan. 31, 2006       Alan Greenspan  Aug. 11, 1987
# 7   Feb. 1, 2006 - Jan. 31, 2014      Ben S. Bernanke   Feb. 1, 2006
# 8    Feb. 3, 2014 - Feb. 3, 2018      Janet L. Yellen   Feb. 3, 2014
# 9                 Feb. 5, 2018 -     Jerome H. Powell   Feb. 5, 2018
#
#      TermEndDate
# 0  Jan. 31, 1948
# 1  Mar. 31, 1951
# 2  Jan. 31, 1970
# 3  Jan. 31, 1978
# 4   Aug. 6, 1979
# 5  Aug. 11, 1987
# 6  Jan. 31, 2006
# 7  Jan. 31, 2014
# 8   Feb. 3, 2018
# 9           None

# %%
chairs_terms = chairs[["Appointee", "TermBeginDate", "TermEndDate"]].copy(deep=True)
chairs_terms.rename(columns={"Appointee": "Name"}, inplace=True)
chairs_terms["Officier"] = "Chair"
chairs_terms.to_csv("../data/bog/chairs_terms.csv", index=False)
chairs_terms
# Out:
#                   Name  TermBeginDate    TermEndDate Officier
# 0   Marriner S. Eccles   Feb. 1, 1936  Jan. 31, 1948    Chair
# 1     Thomas B. McCabe  Apr. 15, 1948  Mar. 31, 1951    Chair
# 2  Wm. McC. Martin, Jr   Apr. 2, 1951  Jan. 31, 1970    Chair
# 3      Arthur F. Burns   Feb. 1, 1970  Jan. 31, 1978    Chair
# 4    G. William Miller   Mar. 8, 1978   Aug. 6, 1979    Chair
# 5      Paul A. Volcker   Aug. 6, 1979  Aug. 11, 1987    Chair
# 6       Alan Greenspan  Aug. 11, 1987  Jan. 31, 2006    Chair
# 7      Ben S. Bernanke   Feb. 1, 2006  Jan. 31, 2014    Chair
# 8      Janet L. Yellen   Feb. 3, 2014   Feb. 3, 2018    Chair
# 9     Jerome H. Powell   Feb. 5, 2018           None    Chair

# %% [markdown]
# ### 副主席任期表

# %%
vice_chairs = pd.DataFrame(vice_chair_table[1:], columns=vice_chair_table[0])
vice_chairs[["TermBeginDate", "TermEndDate"]] = vice_chairs["Date of term"].apply(
    split_term
)
# 保存到本地
vice_chairs.to_csv("../data/bog/vice_chairs.csv", index=False)
vice_chairs
# Out:
#                         Date of term               Appointee   TermBeginDate  \
# 0        Aug. 6, 1936 - Dec. 2, 1947           Ronald Ransom    Aug. 6, 1936
# 1      Mar. 11, 1955 - Feb. 28, 1966     C. Canby Balderston   Mar. 11, 1955
# 2       Mar. 1, 1966 - Apr. 30, 1973          J.L. Robertson    Mar. 1, 1966
# 3        May 1, 1973 - Feb. 13, 1976      George W. Mitchell     May 1, 1973
# 4      Feb. 13, 1976 - Nov. 19, 1978      Stephen S. Gardner   Feb. 13, 1976
# 5      July 27, 1979 - Feb. 11, 1982    Frederick H. Schultz   July 27, 1979
# 6      Mar. 31, 1982 - Apr. 30, 1986          Preston Martin   Mar. 31, 1982
# 7        Aug. 4, 1986 - Aug. 3, 1990       Manuel H. Johnson    Aug. 4, 1986
# 8      July 24, 1991 - Feb. 14, 1994   David W. Mullins, Jr.   July 24, 1991
# 9      June 27, 1994 - Jan. 31, 1996         Alan S. Blinder   June 27, 1994
# 10     June 25, 1996 - July 16, 1999         Alice M. Rivlin   June 25, 1996
# 11      Oct. 5, 1999 - Apr. 28, 2006  Roger W. Ferguson, Jr.    Oct. 5, 1999
# 12     June 23, 2006 - June 23, 2010          Donald L. Kohn   June 23, 2006
# 13       Oct. 4, 2010 - Feb. 3, 2014         Janet L. Yellen    Oct. 4, 2010
# 14     June 16, 2014 - Oct. 16, 2017         Stanley Fischer   June 16, 2014
# 15    Sept. 17, 2018 - Jan. 14, 2022      Richard H. Clarida  Sept. 17, 2018
# 16  May 23, 2022 - February 18, 2023           Lael Brainard    May 23, 2022
# 17                  Sept. 13, 2023 -     Philip N. Jefferson  Sept. 13, 2023
#
#           TermEndDate
# 0        Dec. 2, 1947
# 1       Feb. 28, 1966
# 2       Apr. 30, 1973
# 3       Feb. 13, 1976
# 4       Nov. 19, 1978
# 5       Feb. 11, 1982
# 6       Apr. 30, 1986
# 7        Aug. 3, 1990
# 8       Feb. 14, 1994
# 9       Jan. 31, 1996
# 10      July 16, 1999
# 11      Apr. 28, 2006
# 12      June 23, 2010
# 13       Feb. 3, 2014
# 14      Oct. 16, 2017
# 15      Jan. 14, 2022
# 16  February 18, 2023
# 17               None

# %%
vice_chairs_terms = vice_chairs[["Appointee", "TermBeginDate", "TermEndDate"]].copy(
    deep=True
)
vice_chairs_terms.rename(columns={"Appointee": "Name"}, inplace=True)
vice_chairs_terms["Officier"] = "Vice Chair"
vice_chairs.to_csv("../data/bog/vice_chair_terms.csv", index=False)
vice_chairs_terms
# Out:
#                       Name   TermBeginDate        TermEndDate    Officier
# 0            Ronald Ransom    Aug. 6, 1936       Dec. 2, 1947  Vice Chair
# 1      C. Canby Balderston   Mar. 11, 1955      Feb. 28, 1966  Vice Chair
# 2           J.L. Robertson    Mar. 1, 1966      Apr. 30, 1973  Vice Chair
# 3       George W. Mitchell     May 1, 1973      Feb. 13, 1976  Vice Chair
# 4       Stephen S. Gardner   Feb. 13, 1976      Nov. 19, 1978  Vice Chair
# 5     Frederick H. Schultz   July 27, 1979      Feb. 11, 1982  Vice Chair
# 6           Preston Martin   Mar. 31, 1982      Apr. 30, 1986  Vice Chair
# 7        Manuel H. Johnson    Aug. 4, 1986       Aug. 3, 1990  Vice Chair
# 8    David W. Mullins, Jr.   July 24, 1991      Feb. 14, 1994  Vice Chair
# 9          Alan S. Blinder   June 27, 1994      Jan. 31, 1996  Vice Chair
# 10         Alice M. Rivlin   June 25, 1996      July 16, 1999  Vice Chair
# 11  Roger W. Ferguson, Jr.    Oct. 5, 1999      Apr. 28, 2006  Vice Chair
# 12          Donald L. Kohn   June 23, 2006      June 23, 2010  Vice Chair
# 13         Janet L. Yellen    Oct. 4, 2010       Feb. 3, 2014  Vice Chair
# 14         Stanley Fischer   June 16, 2014      Oct. 16, 2017  Vice Chair
# 15      Richard H. Clarida  Sept. 17, 2018      Jan. 14, 2022  Vice Chair
# 16           Lael Brainard    May 23, 2022  February 18, 2023  Vice Chair
# 17     Philip N. Jefferson  Sept. 13, 2023               None  Vice Chair

# %% [markdown]
# ### 监管副主席任期表

# %%
supervision_vice_chairs = pd.DataFrame(
    supervision_vice_chair_table[1:], columns=supervision_vice_chair_table[0]
)
supervision_vice_chairs[["TermBeginDate", "TermEndDate"]] = supervision_vice_chairs[
    "Date of term"
].apply(split_term)
# 保存到本地
supervision_vice_chairs.to_csv("../data/bog/supervision_vice_chairs.csv", index=False)
supervision_vice_chairs
# Out:
#                     Date of term          Appointee  TermBeginDate  \
# 0  Oct. 13, 2017 - Oct. 13, 2021  Randal K. Quarles  Oct. 13, 2017
# 1                July 19, 2022 -    Michael S. Barr  July 19, 2022
#
#      TermEndDate
# 0  Oct. 13, 2021
# 1           None

# %%
supervision_vice_chairs_terms = supervision_vice_chairs[
    ["Appointee", "TermBeginDate", "TermEndDate"]
].copy(deep=True)
supervision_vice_chairs_terms.rename(columns={"Appointee": "Name"}, inplace=True)
supervision_vice_chairs_terms["Officier"] = "Vice Chair for Supervision"
# supervision_vice_chairs_terms["TermEndDate"] = supervision_vice_chairs_terms[
#     "TermEndDate"
# ].fillna(today)
supervision_vice_chairs.to_csv("../data/bog/supervision_vice_chair_terms.csv", index=False)
supervision_vice_chairs_terms
# Out:
#                 Name  TermBeginDate    TermEndDate                    Officier
# 0  Randal K. Quarles  Oct. 13, 2017  Oct. 13, 2021  Vice Chair for Supervision
# 1    Michael S. Barr  July 19, 2022           None  Vice Chair for Supervision

# %% [markdown]
# ### 理事任期表

# %%
import re
"John Skelton Williams2".strip("0123456789 ")
# Out:
# 'John Skelton Williams'

# %%
governors = pd.DataFrame(governors_table[1:], columns=governors_table[0])
# 分离Name and District
governors[["Name", "District"]] = governors["Name and District"].str.split('\n', expand=True)
governors["Name"] = governors["Name"].str.strip("0123456789 ")
governors["District"] = governors["District"].str.strip()
# 将日期转为 datetime
# governors["TermBeginDate"] = governors["Date of initial oath of office"].transform(
#     lambda x: parse_datestring(x)
# )
governors["TermBeginDate"] = governors["Date of initial oath of office"]
# 保存到本地
governors.to_csv("../data/bog/governors.csv", index=False)
governors
# Out:
#                                      Name and District  \
# 0      W.G. McAdoo\n\t\t\t   Secretary of the Treasury
# 1    John Skelton Williams2\n\t\t\t   Comptroller o...
# 2                   Charles S. Hamlin\n\t\t\t   Boston
# 3                   Paul M. Warburg\n\t\t\t   New York
# 4                 Frederic A. Delano\n\t\t\t   Chicago
# ..                                                 ...
# 108        Christopher J. Waller\n\t\t\t   Minneapolis
# 109                     Lisa D. Cook\n\t\t\t   Atlanta
# 110             Philip N. Jefferson\n\t\t\t   New York
# 111                  Michael S. Barr\n\t\t\t   Chicago
# 112               Adriana D. Kugler\n\t\t\t   Richmond
#
#     Date of initial oath of office  \
# 0                    Dec. 23, 1913
# 1                     Feb. 2, 1914
# 2                    Aug. 10, 1914
# 3                    Aug. 10, 1914
# 4                    Aug. 10, 1914
# ..                             ...
# 108                  Dec. 18, 2020
# 109                   May 23, 2022
# 110                   May 23, 2022
# 111                  July 19, 2022
# 112                 Sept. 13, 2023
#
#     Other dates and information relating to membership                   Name  \
# 0                                        Dec. 15, 1918            W.G. McAdoo
# 1                                         Mar. 2, 1921  John Skelton Williams
# 2    Reappointed in 1916 and 1926. Served until Feb...      Charles S. Hamlin
# 3                           Term expired Aug. 9, 1918.        Paul M. Warburg
# 4                              Resigned July 21, 1918.     Frederic A. Delano
# ..                                                 ...                    ...
# 108                                                     Christopher J. Waller
# 109                        Reappointed Sept. 13, 2023.           Lisa D. Cook
# 110                                                       Philip N. Jefferson
# 111                                                           Michael S. Barr
# 112                                                         Adriana D. Kugler
#
#                         District   TermBeginDate
# 0      Secretary of the Treasury   Dec. 23, 1913
# 1    Comptroller of the Currency    Feb. 2, 1914
# 2                         Boston   Aug. 10, 1914
# 3                       New York   Aug. 10, 1914
# 4                        Chicago   Aug. 10, 1914
# ..                           ...             ...
# 108                  Minneapolis   Dec. 18, 2020
# 109                      Atlanta    May 23, 2022
# 110                     New York    May 23, 2022
# 111                      Chicago   July 19, 2022
# 112                     Richmond  Sept. 13, 2023
#
# [113 rows x 6 columns]

# %%
governors.loc[governors["Name"] == "Janet L. Yellen"]
# Out:
#                           Name and District Date of initial oath of office  \
# 86  Janet L. Yellen\n\t\t\t   San Francisco                  Aug. 12, 1994
#
#    Other dates and information relating to membership             Name  \
# 86  Resigned Feb. 17, 1997; reappointed Oct. 4, 20...  Janet L. Yellen
#
#          District  TermBeginDate
# 86  San Francisco  Aug. 12, 1994

# %% [markdown]
# ### 任期结束时间处理

# %%
# 任期结束日期 
options = [
    "Resigned",
    "resigned",
    "Died",
    "Retired",
    "Served until",
    "Served through",
    "Term expired",
    "term expired",
]

term_end_pattern = (
    # r"(?<=" + "[" + "|".join(options) + "]" + r"\s)[A-Za-z]+.\s\d{1,2},\s\d{4}"
    r"(" + "|".join(options) + r")\s([A-Za-z]+.\s\d{1,2},\s\d{4})"
)
print(term_end_pattern)
end_date_pattern = r"^(Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Sept|Oct|Nov|Dec).\s+(\d{1,2}),\s+(\d{4})$"
print(end_date_pattern)


def match_resign_date(desc: str):
    """匹配纯粹的日期字符串

    Args:
        desc (str): _description_

    Returns:
        _type_: _description_
    """
    match = re.findall(end_date_pattern, desc)
    if match:
        return [desc]
    else:
        return []

def get_resigned_dates(desc: str):
    """获取任期结束日期

    Args:
        desc (_type_): _description_

    Returns:
        _type_: _description_
    """
    if desc is None or pd.isna(desc):
        return "No resigned match found"

    # 匹配辞职期末日期
    resign_date = match_resign_date(desc)
    if resign_date:
        return resign_date
    match = re.findall(term_end_pattern, desc)
    match = [x[1] for x in match]

    if match:
        return match
    else:
        return []

term_end_examples = [
    "Mar. 4, 1933",
    "Term expired Jan. 31, 1996",
    "term expired Jan. 31, 1996",
    "Served until Sept. 1, 1950",
    "Served through Sept. 1, 1950",
    "Died Oct. 21, 1996",
    "Retired Apr. 30, 1967",
    "Resigned Dec. 31, 1996",
    "resigned Dec. 31, 1996",
    "reappointed Aug. 9, 1918.",
    "dadfaddafmwqeasd Aug. 9, 1918.",
]
for example in term_end_examples:
    match = get_resigned_dates(example)
    print(match)
# Out:
# (Resigned|resigned|Died|Retired|Served until|Served through|Term expired|term expired)\s([A-Za-z]+.\s\d{1,2},\s\d{4})
# ^(Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Sept|Oct|Nov|Dec).\s+(\d{1,2}),\s+(\d{4})$
# ['Mar. 4, 1933']
# ['Jan. 31, 1996']
# ['Jan. 31, 1996']
# ['Sept. 1, 1950']
# ['Sept. 1, 1950']
# ['Oct. 21, 1996']
# ['Apr. 30, 1967']
# ['Dec. 31, 1996']
# ['Dec. 31, 1996']
# []
# []

# %%
def get_reappointed_dates(desc):
    if desc is None or pd.isna(desc): 
        return "No resigned match found"
    # 再次任期日期
    options = [
        "Reappointed",
        "reappointed",
    ]
    reappointed_pattern = (
        # r"(?<=" + "[" + "|".join(options) + "]" + r"\s)[A-Za-z]+.\s\d{1,2},\s\d{4}"
        r"(" + "|".join(options) + r")\s([A-Za-z]+.\s\d{1,2},\s\d{4})"
    )
    match = re.findall(reappointed_pattern, desc)
    match = [x[1] for x in match]
    if match:
        return match
    else:
        return []

reappoint_examples = [
    "Reappointed Aug. 9, 1918.",
    "reappointed Aug. 9, 1918.",
    "Term expired Aug. 9, 1918.",
    "Term1 expired Oct. 9, 1918.",
]
for example in reappoint_examples:
    match = get_reappointed_dates(example)
    print(match)
# Out:
# ['Aug. 9, 1918']
# ['Aug. 9, 1918']
# []
# []

# %%
# 再任命和辞职信息登记.
resigns = []
reappoints = []

governor_term_info = {}
for index, row in governors.iterrows():
    if row["Other dates and information relating to membership"] != "":
        # 辞职记录
        resign_dates = get_resigned_dates(row["Other dates and information relating to membership"])
        for resign_date in resign_dates:
            res = row.to_dict()
            res.update({"TermEndDate": resign_date})
            resigns.append(res)
        # 再职记录
        reappoint_dates = get_reappointed_dates(row["Other dates and information relating to membership"])
        for reappoint_date in reappoint_dates:
            res = row.to_dict()
            res.update({"ReappointedDate": reappoint_date})
            reappoints.append(res)
        # 辞职、在职、辞职... 交替拆入队列
        term_info = {"resign_dates": resign_dates, "reappoint_dates": reappoint_dates}
        governor_term_info.update({row['Name']: term_info})
        
json_dump(governor_term_info, "../data/bog/governor_term_info.json")
# 新增辞职记录和再职记录若干行
resigned = pd.DataFrame(resigns)
reappointed = pd.DataFrame(reappoints)
# governors = pd.concat([governors, resigned, reappointed], axis=0)
# governors.loc[governors["Date"]>=pd.to_datetime("2010-01-01", format="%Y-%m-%d")]
# governors

# %%
print(f"resigned: {len(resigned)}")
print(f"reappointed: {len(reappointed)}")
print(f"total: {len(resigned)+len(reappointed)}")
# Out:
# resigned: 107
# reappointed: 5
# total: 112

# %%
resigned
# Out:
#                                      Name and District  \
# 0      W.G. McAdoo\n\t\t\t   Secretary of the Treasury
# 1    John Skelton Williams2\n\t\t\t   Comptroller o...
# 2                   Paul M. Warburg\n\t\t\t   New York
# 3                 Frederic A. Delano\n\t\t\t   Chicago
# 4                     W.P.G. Harding\n\t\t\t   Atlanta
# ..                                                 ...
# 102                  Jeremy C. Stein\n\t\t\t   Chicago
# 103                 Stanley Fischer\n\t\t\t   New York
# 104                   Lael Brainard\n\t\t\t   Richmond
# 105            Randal K. Quarles\n\t\t\t   Kansas City
# 106                Richard H. Clarida\n\t\t\t   Boston
#
#     Date of initial oath of office  \
# 0                    Dec. 23, 1913
# 1                     Feb. 2, 1914
# 2                    Aug. 10, 1914
# 3                    Aug. 10, 1914
# 4                    Aug. 10, 1914
# ..                             ...
# 102                   May 30, 2012
# 103                   May 28, 2014
# 104                  June 16, 2014
# 105                  Oct. 13, 2017
# 106                 Sept. 17, 2018
#
#     Other dates and information relating to membership                   Name  \
# 0                                        Dec. 15, 1918            W.G. McAdoo
# 1                                         Mar. 2, 1921  John Skelton Williams
# 2                           Term expired Aug. 9, 1918.        Paul M. Warburg
# 3                              Resigned July 21, 1918.     Frederic A. Delano
# 4                           Term expired Aug. 9, 1922.         W.P.G. Harding
# ..                                                 ...                    ...
# 102                             Resigned May 28, 2014.        Jeremy C. Stein
# 103                            Resigned Oct. 16, 2017.        Stanley Fischer
# 104                            Resigned Feb. 18, 2023.          Lael Brainard
# 105                            Resigned Dec. 25, 2021.      Randal K. Quarles
# 106                            Resigned Jan. 14, 2022.     Richard H. Clarida
#
#                         District   TermBeginDate    TermEndDate
# 0      Secretary of the Treasury   Dec. 23, 1913  Dec. 15, 1918
# 1    Comptroller of the Currency    Feb. 2, 1914   Mar. 2, 1921
# 2                       New York   Aug. 10, 1914   Aug. 9, 1918
# 3                        Chicago   Aug. 10, 1914  July 21, 1918
# 4                        Atlanta   Aug. 10, 1914   Aug. 9, 1922
# ..                           ...             ...            ...
# 102                      Chicago    May 30, 2012   May 28, 2014
# 103                     New York    May 28, 2014  Oct. 16, 2017
# 104                     Richmond   June 16, 2014  Feb. 18, 2023
# 105                  Kansas City   Oct. 13, 2017  Dec. 25, 2021
# 106                       Boston  Sept. 17, 2018  Jan. 14, 2022
#
# [107 rows x 7 columns]

# %%
reappointed
# Out:
#                          Name and District Date of initial oath of office  \
# 0  Janet L. Yellen\n\t\t\t   San Francisco                  Aug. 12, 1994
# 1        Ben S. Bernanke\n\t\t\t   Atlanta                   Aug. 5, 2002
# 2  Jerome H. Powell\n\t\t\t   Philadelphia                   May 25, 2012
# 3   Michelle W. Bowman\n\t\t\t   St. Louis                  Nov. 26, 2018
# 4           Lisa D. Cook\n\t\t\t   Atlanta                   May 23, 2022
#
#   Other dates and information relating to membership                Name  \
# 0  Resigned Feb. 17, 1997; reappointed Oct. 4, 20...     Janet L. Yellen
# 1  Resigned June 21, 2005; reappointed Feb. 1, 20...     Ben S. Bernanke
# 2                         Reappointed June 16, 2014.    Jerome H. Powell
# 3                         Reappointed Jan. 30, 2020.  Michelle W. Bowman
# 4                        Reappointed Sept. 13, 2023.        Lisa D. Cook
#
#         District  TermBeginDate ReappointedDate
# 0  San Francisco  Aug. 12, 1994    Oct. 4, 2010
# 1        Atlanta   Aug. 5, 2002    Feb. 1, 2006
# 2   Philadelphia   May 25, 2012   June 16, 2014
# 3      St. Louis  Nov. 26, 2018   Jan. 30, 2020
# 4        Atlanta   May 23, 2022  Sept. 13, 2023

# %% [markdown]
# #### 理事的任期表
#
# <!-- name, begin_date, resign_date, district -->

# %%
governor_term_info
# Out:
# {'W.G. McAdoo': {'resign_dates': ['Dec. 15, 1918'], 'reappoint_dates': []},
#  'John Skelton Williams': {'resign_dates': ['Mar. 2, 1921'],
#   'reappoint_dates': []},
#  'Charles S. Hamlin': {'resign_dates': [], 'reappoint_dates': []},
#  'Paul M. Warburg': {'resign_dates': ['Aug. 9, 1918'], 'reappoint_dates': []},
#  'Frederic A. Delano': {'resign_dates': ['July 21, 1918'],
#   'reappoint_dates': []},
#  'W.P.G. Harding': {'resign_dates': ['Aug. 9, 1922'], 'reappoint_dates': []},
#  'Adolph C. Miller': {'resign_dates': ['Feb.\xa03,\xa01936'],
#   'reappoint_dates': []},
#  'Albert Strauss': {'resign_dates': ['Mar. 15, 1920'], 'reappoint_dates': []},
#  'Carter Glass': {'resign_dates': ['Feb. 1, 1920'], 'reappoint_dates': []},
#  'Henry A. Moehlenpah': {'resign_dates': ['Aug. 9, 1920'],
#   'reappoint_dates': []},
#  'David F. Houston': {'resign_dates': ['Mar. 3, 1921'], 'reappoint_dates': []},
#  'Edmund Platt': {'resign_dates': ['Sept. 14, 1930'], 'reappoint_dates': []},
#  'David C. Wills': {'resign_dates': ['Mar. 4, 1921'], 'reappoint_dates': []},
#  'Andrew W. Mellon': {'resign_dates': ['Feb. 12, 1932'],
#   'reappoint_dates': []},
#  'John R. Mitchell': {'resign_dates': ['May 12, 1923'], 'reappoint_dates': []},
#  'Milo D. Campbell': {'resign_dates': ['Mar. 22, 1923'],
#   'reappoint_dates': []},
#  'Daniel R. Crissinger': {'resign_dates': ['Sept. 15, 1927'],
#   'reappoint_dates': []},
#  'Henry M. Dawes': {'resign_dates': ['Dec. 17, 1924'], 'reappoint_dates': []},
#  'George R. James': {'resign_dates': ['Feb. 3, 1936'], 'reappoint_dates': []},
#  'Edward H. Cunningham': {'resign_dates': ['Nov. 28, 1930'],
#   'reappoint_dates': []},
#  'Joseph W. McIntosh': {'resign_dates': ['Nov. 20, 1928'],
#   'reappoint_dates': []},
#  'Roy A. Young': {'resign_dates': ['Aug. 31, 1930'], 'reappoint_dates': []},
#  'J.W. Pole': {'resign_dates': ['Sept. 20, 1932'], 'reappoint_dates': []},
#  'Eugene Meyer': {'resign_dates': ['May 10, 1933'], 'reappoint_dates': []},
#  'Wayland W. Magee': {'resign_dates': ['Jan. 24, 1933'],
#   'reappoint_dates': []},
#  'Ogden L. Mills': {'resign_dates': ['Mar. 4, 1933'], 'reappoint_dates': []},
#  'William H. Woodin': {'resign_dates': ['Dec. 31, 1933'],
#   'reappoint_dates': []},
#  "J.F.T. O'Connor": {'resign_dates': ['Feb. 1, 1936'], 'reappoint_dates': []},
#  'Eugene R. Black': {'resign_dates': ['Aug. 15, 1934'], 'reappoint_dates': []},
#  'M.S. Szymczak': {'resign_dates': ['May 31, 1961'], 'reappoint_dates': []},
#  'J.J. Thomas': {'resign_dates': ['Feb. 10, 1936'], 'reappoint_dates': []},
#  'Henry Morgenthau, Jr.': {'resign_dates': ['Feb. 1, 1936'],
#   'reappoint_dates': []},
#  'Marriner S. Eccles': {'resign_dates': ['July\xa014,\xa01951'],
#   'reappoint_dates': []},
#  'Joseph A. Broderick': {'resign_dates': ['Sept. 30, 1937'],
#   'reappoint_dates': []},
#  'John K. McKee': {'resign_dates': ['Apr. 4, 1946'], 'reappoint_dates': []},
#  'Ronald Ransom': {'resign_dates': ['Dec. 2, 1947'], 'reappoint_dates': []},
#  'Ralph W. Morrison': {'resign_dates': ['July 9, 1936'],
#   'reappoint_dates': []},
#  'Chester C. Davis': {'resign_dates': ['Apr. 15, 1941'],
#   'reappoint_dates': []},
#  'Ernest G. Draper': {'resign_dates': ['Sept. 1, 1950'],
#   'reappoint_dates': []},
#  'Rudolph M. Evans': {'resign_dates': ['Aug. 13, 1954'],
#   'reappoint_dates': []},
#  'James K. Vardaman, Jr.': {'resign_dates': ['Nov. 30, 1958'],
#   'reappoint_dates': []},
#  'Lawrence Clayton': {'resign_dates': ['Dec. 4, 1949'], 'reappoint_dates': []},
#  'Thomas B. McCabe': {'resign_dates': ['Mar. 31, 1951'],
#   'reappoint_dates': []},
#  'Edward L. Norton': {'resign_dates': ['Jan. 31, 1952'],
#   'reappoint_dates': []},
#  'Oliver S. Powell': {'resign_dates': ['June 30, 1952'],
#   'reappoint_dates': []},
#  'Wm. McC. Martin, Jr.': {'resign_dates': ['Jan. 31, 1970'],
#   'reappoint_dates': []},
#  'A.L. Mills, Jr.': {'resign_dates': ['Feb. 28, 1965'], 'reappoint_dates': []},
#  'J.L. Robertson': {'resign_dates': ['Apr. 30, 1973'], 'reappoint_dates': []},
#  'C. Canby Balderston': {'resign_dates': ['Feb. 28, 1966'],
#   'reappoint_dates': []},
#  'Paul E. Miller': {'resign_dates': ['Oct. 21, 1954'], 'reappoint_dates': []},
#  'Chas. N. Shepardson': {'resign_dates': ['Apr. 30, 1967'],
#   'reappoint_dates': []},
#  'G.H. King, Jr.': {'resign_dates': ['Sept. 18, 1963'], 'reappoint_dates': []},
#  'George W. Mitchell': {'resign_dates': ['Feb. 13, 1976'],
#   'reappoint_dates': []},
#  'J. Dewey Daane': {'resign_dates': ['Mar. 8, 1974'], 'reappoint_dates': []},
#  'Sherman J. Maisel': {'resign_dates': ['May 31, 1972'],
#   'reappoint_dates': []},
#  'Andrew F. Brimmer': {'resign_dates': ['Aug. 31, 1974'],
#   'reappoint_dates': []},
#  'William W. Sherrill': {'resign_dates': ['Nov. 15, 1971'],
#   'reappoint_dates': []},
#  'Arthur F. Burns': {'resign_dates': ['Mar. 31, 1978'], 'reappoint_dates': []},
#  'John E. Sheehan': {'resign_dates': ['June 1, 1975'], 'reappoint_dates': []},
#  'Jeffrey M. Bucher': {'resign_dates': ['Jan. 2, 1976'],
#   'reappoint_dates': []},
#  'Robert C. Holland': {'resign_dates': ['May 15, 1976'],
#   'reappoint_dates': []},
#  'Henry C. Wallich': {'resign_dates': ['Dec. 15, 1986'],
#   'reappoint_dates': []},
#  'Philip E. Coldwell': {'resign_dates': ['Feb. 29, 1980'],
#   'reappoint_dates': []},
#  'Philip C. Jackson, Jr.': {'resign_dates': ['Nov. 17, 1978'],
#   'reappoint_dates': []},
#  'J. Charles Partee': {'resign_dates': ['Feb. 7, 1986'],
#   'reappoint_dates': []},
#  'Stephen S. Gardner': {'resign_dates': ['Nov. 19, 1978'],
#   'reappoint_dates': []},
#  'David M. Lilly': {'resign_dates': ['Feb. 24, 1978'], 'reappoint_dates': []},
#  'G. William Miller': {'resign_dates': ['Aug. 6, 1979'],
#   'reappoint_dates': []},
#  'Nancy H. Teeters': {'resign_dates': ['June 27, 1984'],
#   'reappoint_dates': []},
#  'Emmett J. Rice': {'resign_dates': ['Dec. 31, 1986'], 'reappoint_dates': []},
#  'Frederick H. Schultz': {'resign_dates': ['Feb. 11, 1982'],
#   'reappoint_dates': []},
#  'Paul A. Volcker': {'resign_dates': ['August 11, 1987'],
#   'reappoint_dates': []},
#  'Lyle E. Gramley': {'resign_dates': ['Sept. 1, 1985'], 'reappoint_dates': []},
#  'Preston Martin': {'resign_dates': ['April 30, 1986'], 'reappoint_dates': []},
#  'Martha R. Seger': {'resign_dates': ['March 11, 1991'],
#   'reappoint_dates': []},
#  'Wayne D. Angell': {'resign_dates': ['Feb. 9, 1994'], 'reappoint_dates': []},
#  'Manuel H. Johnson': {'resign_dates': ['August 3, 1990'],
#   'reappoint_dates': []},
#  'H. Robert Heller': {'resign_dates': ['July 31, 1989'],
#   'reappoint_dates': []},
#  'Edward W. Kelley, Jr.': {'resign_dates': ['Dec. 31, 2001'],
#   'reappoint_dates': []},
#  'Alan Greenspan': {'resign_dates': ['Jan. 31, 2006'], 'reappoint_dates': []},
#  'John P. LaWare': {'resign_dates': ['April 30, 1995'], 'reappoint_dates': []},
#  'David W. Mullins, Jr.': {'resign_dates': ['Feb. 14, 1994'],
#   'reappoint_dates': []},
#  'Lawrence B. Lindsey': {'resign_dates': ['Feb. 5, 1997'],
#   'reappoint_dates': []},
#  'Susan M. Phillips': {'resign_dates': ['June 30, 1998'],
#   'reappoint_dates': []},
#  'Alan S. Blinder': {'resign_dates': ['Jan. 31, 1996'], 'reappoint_dates': []},
#  'Janet L. Yellen': {'resign_dates': ['Feb. 17, 1997', 'Feb. 3, 2018'],
#   'reappoint_dates': ['Oct. 4, 2010']},
#  'Laurence H. Meyer': {'resign_dates': ['Jan. 31, 2002'],
#   'reappoint_dates': []},
#  'Alice M. Rivlin': {'resign_dates': ['July 16, 1999'], 'reappoint_dates': []},
#  'Roger W. Ferguson, Jr.': {'resign_dates': ['April 28, 2006'],
#   'reappoint_dates': []},
#  'Edward M. Gramlich': {'resign_dates': ['August 31, 2005'],
#   'reappoint_dates': []},
#  'Susan S. Bies': {'resign_dates': ['March 30, 2007'], 'reappoint_dates': []},
#  'Mark W. Olson': {'resign_dates': ['June 30, 2006'], 'reappoint_dates': []},
#  'Ben S. Bernanke': {'resign_dates': ['June 21, 2005', 'Jan. 31, 2014'],
#   'reappoint_dates': ['Feb. 1, 2006']},
#  'Donald L. Kohn': {'resign_dates': ['September 1, 2010'],
#   'reappoint_dates': []},
#  'Kevin M. Warsh': {'resign_dates': ['April 2, 2011'], 'reappoint_dates': []},
#  'Randall S. Kroszner': {'resign_dates': ['January 21, 2009'],
#   'reappoint_dates': []},
#  'Frederic S. Mishkin': {'resign_dates': ['August 31, 2008'],
#   'reappoint_dates': []},
#  'Elizabeth A. Duke': {'resign_dates': ['August 31, 2013'],
#   'reappoint_dates': []},
#  'Daniel K. Tarullo': {'resign_dates': ['April 5, 2017'],
#   'reappoint_dates': []},
#  'Sarah Bloom Raskin': {'resign_dates': ['March 13, 2014'],
#   'reappoint_dates': []},
#  'Jerome H. Powell': {'resign_dates': [],
#   'reappoint_dates': ['June 16, 2014']},
#  'Jeremy C. Stein': {'resign_dates': ['May 28, 2014'], 'reappoint_dates': []},
#  'Stanley Fischer': {'resign_dates': ['Oct. 16, 2017'], 'reappoint_dates': []},
#  'Lael Brainard': {'resign_dates': ['Feb. 18, 2023'], 'reappoint_dates': []},
#  'Randal K. Quarles': {'resign_dates': ['Dec. 25, 2021'],
#   'reappoint_dates': []},
#  'Richard H. Clarida': {'resign_dates': ['Jan. 14, 2022'],
#   'reappoint_dates': []},
#  'Michelle W. Bowman': {'resign_dates': [],
#   'reappoint_dates': ['Jan. 30, 2020']},
#  'Lisa D. Cook': {'resign_dates': [], 'reappoint_dates': ['Sept. 13, 2023']}}

# %%
governor_terms = governors[["Name", "District", "TermBeginDate"]].copy(deep=True)
governor_terms['TermEndDate'] = [None]*governor_terms.shape[0]
governor_terms['Officier'] = 'Governor'

# 根据辞任表更新理事们的任期结束时间
# 如果有辞任表，则更新其辞任时间；重新任命的职务要手动调整。因此，此处直接使用第一个辞任时间。
for person, term_info in governor_term_info.items():
    # 用第一个辞任时间更新表的辞任时间
    if len(term_info["resign_dates"])!=0:
        governor_terms.loc[governor_terms["Name"] == person, "TermEndDate"] = term_info["resign_dates"][0]

# 根据重任命表，手动维护若干人的信息
governor_terms.loc[governor_terms["Name"] == "Charles S. Hamlin", "TermEndDate"] = (
    "Feb. 1, 1936"
)
reappoint_terms = pd.DataFrame(
    data=[
        ["Janet L. Yellen", "San Francisco", "Feb. 1, 1936", "Feb. 1, 1936", "Governor"],
    ],
    columns=governor_terms.columns
)
# 其他人均填为当前日期
# governor_terms["TermEndDate"] = governor_terms["TermEndDate"].fillna(today)
governor_terms
# Out:
#                       Name                     District   TermBeginDate  \
# 0              W.G. McAdoo    Secretary of the Treasury   Dec. 23, 1913
# 1    John Skelton Williams  Comptroller of the Currency    Feb. 2, 1914
# 2        Charles S. Hamlin                       Boston   Aug. 10, 1914
# 3          Paul M. Warburg                     New York   Aug. 10, 1914
# 4       Frederic A. Delano                      Chicago   Aug. 10, 1914
# ..                     ...                          ...             ...
# 108  Christopher J. Waller                  Minneapolis   Dec. 18, 2020
# 109           Lisa D. Cook                      Atlanta    May 23, 2022
# 110    Philip N. Jefferson                     New York    May 23, 2022
# 111        Michael S. Barr                      Chicago   July 19, 2022
# 112      Adriana D. Kugler                     Richmond  Sept. 13, 2023
#
#        TermEndDate  Officier
# 0    Dec. 15, 1918  Governor
# 1     Mar. 2, 1921  Governor
# 2     Feb. 1, 1936  Governor
# 3     Aug. 9, 1918  Governor
# 4    July 21, 1918  Governor
# ..             ...       ...
# 108           None  Governor
# 109           None  Governor
# 110           None  Governor
# 111           None  Governor
# 112           None  Governor
#
# [113 rows x 5 columns]

# %% [markdown]
# ## 最终的理事会成员任期表

# %% [markdown]
# ### 手工处理的重任命(reappoint)的任期表

# %%
reappoint_terms = pd.read_excel('../data/bog/reappoint_terms.xlsx')
reappoint_terms = reappoint_terms.replace(np.nan, None)
reappoint_terms
# Out:
#                       Name       District   TermBeginDate     TermEndDate  \
# 0             Lisa D. Cook        Atlanta   May. 23, 2022  Sept. 13, 2023
# 1             Lisa D. Cook        Atlanta  Sept. 13, 2023            None
# 2       Michelle W. Bowman      St. Louis   Nov. 26, 2018   Jan. 30, 2020
# 3       Michelle W. Bowman      St. Louis   Jan. 30, 2020            None
# 4         Jerome H. Powell   Philadelphia   May. 25, 2012   Jun. 16, 2014
# 5         Jerome H. Powell   Philadelphia   Jun. 16, 2014    Feb. 5, 2018
# 6         Jerome H. Powell   Philadelphia    Feb. 5, 2018   May. 23, 2022
# 7         Jerome H. Powell   Philadelphia   May. 23, 2022            None
# 8          Ben S. Bernanke        Atlanta    Aug. 5, 2002   Jun. 21, 2005
# 9          Ben S. Bernanke        Atlanta    Feb. 1, 2006   Jan. 31, 2010
# 10         Ben S. Bernanke        Atlanta    Feb. 1, 2010   Jan. 31, 2014
# 11  Roger W. Ferguson, Jr.         Boston    Nov. 5, 1997    Oct. 5, 1999
# 12  Roger W. Ferguson, Jr.         Boston    Oct. 5, 1999   Apr. 28, 2006
# 13         Janet L. Yellen  San Francisco   Aug. 12, 1994   Feb. 17, 1997
# 14         Janet L. Yellen  San Francisco    Oct. 4, 2010    Feb. 2, 2014
# 15         Janet L. Yellen  San Francisco    Feb. 3, 2014    Feb. 5, 2018
#
#       Officier
# 0     Governor
# 1     Governor
# 2     Governor
# 3     Governor
# 4     Governor
# 5     Governor
# 6        Chair
# 7        Chair
# 8     Governor
# 9        Chair
# 10       Chair
# 11    Governor
# 12  Vice Chair
# 13    Governor
# 14  Vice Chair
# 15       Chair

# %%
bog_terms = pd.concat(
    [
        # governor_terms.loc[
        #     ~governor_terms["Name"].isin(reappoint_terms["Name"].unique().tolist())
        # ],
        # reappoint_terms,
        governor_terms,
        chairs_terms,
        vice_chairs_terms,
        supervision_vice_chairs_terms,
    ],  #
    axis=0,
)
bog_terms = bog_terms.drop_duplicates()
# 填充District
bog_terms["District"] = bog_terms.groupby("Name")["District"].ffill().bfill()

# # 转换格式
bog_terms["TermBeginDate"] = bog_terms["TermBeginDate"].transform(lambda x: parse_datestring(x))
bog_terms["TermEndDate"] = bog_terms["TermEndDate"].transform(lambda x: parse_datestring(x))
bog_terms = bog_terms.sort_values(["Name", "TermBeginDate", "TermEndDate"]).reset_index(drop=True)
# 保存
bog_terms.to_csv("../data/bog/bog_governors_terms.csv", index=False)
bog_terms.info()
bog_terms
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           143 non-null    object
#  1   District       143 non-null    object
#  2   TermBeginDate  143 non-null    datetime64[ns]
#  3   TermEndDate    133 non-null    datetime64[ns]
#  4   Officier       143 non-null    object
# dtypes: datetime64[ns](2), object(3)
# memory usage: 5.7+ KB
#                      Name                   District TermBeginDate  \
# 0         A.L. Mills, Jr.              San Francisco    1952-02-18
# 1        Adolph C. Miller              San Francisco    1914-08-10
# 2       Adriana D. Kugler                   Richmond    2023-09-13
# 3          Alan Greenspan                   New York    1987-08-11
# 4          Alan Greenspan                   New York    1987-08-11
# ..                    ...                        ...           ...
# 138       Wayne D. Angell                Kansas City    1986-02-07
# 139     William H. Woodin  Secretary of the Treasury    1933-03-04
# 140   William W. Sherrill                     Dallas    1967-05-01
# 141   Wm. McC. Martin, Jr                   New York    1951-04-02
# 142  Wm. McC. Martin, Jr.                   New York    1951-04-02
#
#     TermEndDate  Officier
# 0    1965-02-28  Governor
# 1    1936-02-03  Governor
# 2           NaT  Governor
# 3    2006-01-31  Governor
# 4    2006-01-31     Chair
# ..          ...       ...
# 138  1994-02-09  Governor
# 139  1933-12-31  Governor
# 140  1971-11-15  Governor
# 141  1970-01-31     Chair
# 142  1970-01-31  Governor
#
# [143 rows x 5 columns]

# %%
# bog_terms.iloc[0:100, 3].transform(parse_datestring)

# %%
bog_terms.loc[pd.isna(bog_terms['TermEndDate'])].sort_values(by="Name")
# Out:
#                       Name      District TermBeginDate TermEndDate  \
# 2        Adriana D. Kugler      Richmond    2023-09-13         NaT
# 22   Christopher J. Waller   Minneapolis    2020-12-18         NaT
# 71        Jerome H. Powell  Philadelphia    2012-05-25         NaT
# 72        Jerome H. Powell  Philadelphia    2018-02-05         NaT
# 86            Lisa D. Cook       Atlanta    2022-05-23         NaT
# 95         Michael S. Barr       Chicago    2022-07-19         NaT
# 96         Michael S. Barr       Chicago    2022-07-19         NaT
# 97      Michelle W. Bowman     St. Louis    2018-11-26         NaT
# 108    Philip N. Jefferson      New York    2022-05-23         NaT
# 109    Philip N. Jefferson      New York    2023-09-13         NaT
#
#                        Officier
# 2                      Governor
# 22                     Governor
# 71                     Governor
# 72                        Chair
# 86                     Governor
# 95                     Governor
# 96   Vice Chair for Supervision
# 97                     Governor
# 108                    Governor
# 109                  Vice Chair

# %%
# 鲍曼任期查询
# print(bog_terms.query("Name=='Michelle W. Bowman'"))
# print(bog_terms.query("Name=='Jerome H. Powell'"))
bog_terms.loc[
    bog_terms["Name"].isin(
        ["Janet L. Yellen", "Jerome H. Powell", "Ben S. Bernanke", "Michelle W. Bowman"]
    )
].sort_values(by='Name')
# Out:
#                   Name       District TermBeginDate TermEndDate    Officier
# 14     Ben S. Bernanke        Atlanta    2002-08-05  2005-06-21    Governor
# 15     Ben S. Bernanke        Atlanta    2006-02-01  2014-01-31       Chair
# 66     Janet L. Yellen  San Francisco    1994-08-12  1997-02-17    Governor
# 67     Janet L. Yellen  San Francisco    2010-10-04  2014-02-03  Vice Chair
# 68     Janet L. Yellen  San Francisco    2014-02-03  2018-02-03       Chair
# 71    Jerome H. Powell   Philadelphia    2012-05-25         NaT    Governor
# 72    Jerome H. Powell   Philadelphia    2018-02-05         NaT       Chair
# 97  Michelle W. Bowman      St. Louis    2018-11-26         NaT    Governor

# %%
bog_terms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           143 non-null    object
#  1   District       143 non-null    object
#  2   TermBeginDate  143 non-null    datetime64[ns]
#  3   TermEndDate    133 non-null    datetime64[ns]
#  4   Officier       143 non-null    object
# dtypes: datetime64[ns](2), object(3)
# memory usage: 5.7+ KB

# %%
def query_incumbent_governors(date: str, bog_terms: pd.DataFrame):
    # 转为日期格式
    date = parse_datestring(date)
    # 筛选出在任任期
    incumbent = bog_terms.loc[
        (bog_terms["TermBeginDate"] <= date)
        & ((bog_terms["TermEndDate"] >= date) | (pd.isna(bog_terms["TermEndDate"])))
    ].reset_index(drop=True)
    # 筛选出最高职位
    _chair_mapping = {"Chair": 0, "Vice Chair": 1, "Vice Chair for Supervision": 2, "Governor": 3}
    incumbent["Position"] = incumbent["Officier"].map(_chair_mapping)
    incumbent = incumbent.sort_values(
        ["Position", "Name", "TermBeginDate"], ascending=[True, True, False]
    )
    incumbent = incumbent.drop_duplicates(subset=["Name"], keep="first").drop(columns=['Position']).reset_index(drop=True)
    return incumbent

# query_incumbent_governors('Feb. 2, 2020', bog_terms)
query_incumbent_governors("Aug. 25, 2023", bog_terms) #['Name'].unique().tolist()
# Out:
#                     Name      District TermBeginDate TermEndDate  \
# 0       Jerome H. Powell  Philadelphia    2018-02-05         NaT
# 1        Michael S. Barr       Chicago    2022-07-19         NaT
# 2  Christopher J. Waller   Minneapolis    2020-12-18         NaT
# 3           Lisa D. Cook       Atlanta    2022-05-23         NaT
# 4     Michelle W. Bowman     St. Louis    2018-11-26         NaT
# 5    Philip N. Jefferson      New York    2022-05-23         NaT
#
#                      Officier
# 0                       Chair
# 1  Vice Chair for Supervision
# 2                    Governor
# 3                    Governor
# 4                    Governor
# 5                    Governor
